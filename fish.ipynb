# %%
print('hi')
# Out:
# hi

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
fish= pd.read_csv('./Fish.csv')
fish.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
x = fish['Weight'].values
y = fish['Width'].values 
x=x.reshape(-1,1)

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,train_size=0.8,test_size=0.2,random_state=100)

# %%
x_train.shape
# Out:
# (127, 1)

# %%
x_test.shape
# Out:
# (32, 1)

# %%
plt.scatter(x_train,y_train,color='red')
plt.xlabel('Weight')
plt.ylabel('Width')
plt.title('realtion between weight and width')
plt.show()

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test)

# %%
y_test
# Out:
# array([3.8203, 4.8146, 7.5958, 5.58  , 4.69  , 6.2646, 5.376 , 4.3056,
#        1.269 , 3.906 , 6.292 , 1.9992, 6.09  , 6.603 , 6.003 , 3.525 ,
#        3.3957, 3.3516, 6.5736, 4.335 , 5.355 , 6.7497, 3.534 , 1.38  ,
#        3.325 , 1.8792, 7.2772, 5.5695, 6.1984, 3.3216, 3.3756, 1.1659])

# %%
y_predict
# Out:
# array([3.45814642, 4.82599334, 6.83753293, 5.22830126, 4.38345463,
#        5.63060918, 5.91222472, 3.98114671, 2.86836301, 3.538608  ,
#        6.65649437, 2.94319228, 5.71107076, 6.83753293, 5.42945522,
#        3.33745404, 3.25699246, 2.81445375, 6.0329171 , 3.88056973,
#        4.38345463, 6.535802  , 3.33745404, 2.85347761, 3.37768483,
#        2.89451302, 6.83753293, 5.12772428, 6.23407106, 3.21676167,
#        3.61906958, 2.85428223])

# %%
new_fish_Width = np.array([4]).reshape(-1,1)
new_fish_Width
# Out:
# array([[4]])

# %%
model.predict(new_fish_Width)
# Out:
# array([2.83054606])

# %%
new_fish_Width = np.array([25]).reshape(-1,1)
model.predict(new_fish_Width)
# Out:
# array([2.91503073])

# %%
model.score(x_train,y_train)*5
# Out:
# 3.810591373086645

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_test,y_predict,color='blue')
plt.xlabel('Weight')
plt.ylabel('Width')
plt.title('realtion between weight and width')
plt.show()

# %%
y_train
# Out:
# array([7.225 , 3.2928, 4.368 , 5.2854, 2.3142, 4.3225, 6.018 , 3.725 ,
#        1.0476, 6.63  , 4.2042, 3.723 , 3.977 , 5.1296, 3.555 , 2.9044,
#        5.2785, 6.0532, 5.3704, 2.6316, 3.6675, 4.9594, 6.1306, 2.268 ,
#        7.4934, 3.624 , 4.459 , 3.525 , 7.3514, 5.1373, 8.142 , 6.1712,
#        1.3936, 5.2801, 3.6636, 6.9849, 6.7473, 3.2943, 7.48  , 7.4165,
#        4.9274, 2.8217, 3.7544, 4.4968, 6.864 , 2.772 , 6.144 , 5.1042,
#        1.1484, 3.995 , 4.144 , 4.4555, 2.9415, 4.6816, 3.825 , 4.02  ,
#        3.1234, 7.1064, 3.3075, 4.0198, 4.1272, 3.1571, 4.144 , 3.6835,
#        7.7957, 5.0728, 1.408 , 5.1975, 2.432 , 6.3666, 1.16  , 6.7408,
#        2.9181, 5.1338, 3.5478, 3.1746, 3.5742, 3.8   , 3.8352, 6.3063,
#        6.3875, 4.2485, 5.8515, 1.2772, 2.673 , 1.2852, 5.7276, 1.2838,
#        4.5662, 7.4624, 4.6961, 3.0368, 6.8684, 4.234 , 4.2476, 1.1484,
#        2.3265, 3.6312, 1.2558, 3.624 , 5.134 , 4.239 , 4.158 , 4.5765,
# ...

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)

# %%
y_predict
# Out:
# array([3.45814642, 4.82599334, 6.83753293, 5.22830126, 4.38345463,
#        5.63060918, 5.91222472, 3.98114671, 2.86836301, 3.538608  ,
#        6.65649437, 2.94319228, 5.71107076, 6.83753293, 5.42945522,
#        3.33745404, 3.25699246, 2.81445375, 6.0329171 , 3.88056973,
#        4.38345463, 6.535802  , 3.33745404, 2.85347761, 3.37768483,
#        2.89451302, 6.83753293, 5.12772428, 6.23407106, 3.21676167,
#        3.61906958, 2.85428223])

# %%
y_test
# Out:
# array([3.8203, 4.8146, 7.5958, 5.58  , 4.69  , 6.2646, 5.376 , 4.3056,
#        1.269 , 3.906 , 6.292 , 1.9992, 6.09  , 6.603 , 6.003 , 3.525 ,
#        3.3957, 3.3516, 6.5736, 4.335 , 5.355 , 6.7497, 3.534 , 1.38  ,
#        3.325 , 1.8792, 7.2772, 5.5695, 6.1984, 3.3216, 3.3756, 1.1659])

# %%
model.score(x_train,y_train)
import seaborn as sns
sns.set()
plt.figure(figsize=(8,4),dpi=250)
sns.regplot(x='Length1',y='Width',data=fish)
# Out:
# <AxesSubplot:xlabel='Length1', ylabel='Width'>

# %%
x=fish['Length2'].values
y=fish['Width'].values
x=x.reshape(-1,1)
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,test_size=0.3,random_state=100)

# %%
x=fish['Height'].values
y=fish['Width'].values
x=x.reshape(-1,1)
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,test_size=0.3,random_state=100)

# %%
y_train
# Out:
# array([5.2785, 6.0532, 5.3704, 2.6316, 3.6675, 4.9594, 6.1306, 2.268 ,
#        7.4934, 3.624 , 4.459 , 3.525 , 7.3514, 5.1373, 8.142 , 6.1712,
#        1.3936, 5.2801, 3.6636, 6.9849, 6.7473, 3.2943, 7.48  , 7.4165,
#        4.9274, 2.8217, 3.7544, 4.4968, 6.864 , 2.772 , 6.144 , 5.1042,
#        1.1484, 3.995 , 4.144 , 4.4555, 2.9415, 4.6816, 3.825 , 4.02  ,
#        3.1234, 7.1064, 3.3075, 4.0198, 4.1272, 3.1571, 4.144 , 3.6835,
#        7.7957, 5.0728, 1.408 , 5.1975, 2.432 , 6.3666, 1.16  , 6.7408,
#        2.9181, 5.1338, 3.5478, 3.1746, 3.5742, 3.8   , 3.8352, 6.3063,
#        6.3875, 4.2485, 5.8515, 1.2772, 2.673 , 1.2852, 5.7276, 1.2838,
#        4.5662, 7.4624, 4.6961, 3.0368, 6.8684, 4.234 , 4.2476, 1.1484,
#        2.3265, 3.6312, 1.2558, 3.624 , 5.134 , 4.239 , 4.158 , 4.5765,
#        4.7716, 4.3844, 3.4075, 3.63  , 4.896 , 6.562 , 6.525 , 4.6354,
#        6.144 , 2.0672, 6.3705, 5.1708, 3.2944, 4.7736, 4.1658, 3.626 ,
# ...

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_train)
y_predict
# Out:
# array([6.08830649, 6.7738873 , 6.65868583, 3.07398325, 3.41987064,
#        6.10311541, 6.49361822, 2.93400592, 5.13157461, 3.76556939,
#        3.77594506, 3.47725129, 5.53864707, 4.24693798, 5.59294645,
#        4.43659281, 2.28731818, 6.51062805, 4.88293563, 4.98999377,
#        7.48930605, 3.552585  , 5.02951567, 5.56417752, 5.90685788,
#        3.29592845, 3.45508507, 4.42106073, 5.05121027, 3.22792059,
#        4.6484453 , 6.11449722, 2.32316143, 3.36642018, 5.11629407,
#        5.63256268, 3.07259983, 4.38999658, 3.63445854, 5.25212113,
#        3.26476997, 5.3805909 , 3.49061391, 3.60723024, 3.95572727,
#        4.69133143, 3.88378924, 3.65473827, 5.24218563, 6.00448359,
#        2.29410953, 6.32678989, 2.83238715, 4.95396186, 2.2500915 ,
#        4.96572097, 4.26869547, 6.54530796, 3.71586045, 3.39600658,
#        3.58446663, 3.6423189 , 3.99899071, 7.30112898, 4.85485841,
#        4.19109797, 6.82325038, 2.2850544 , 3.95836836, 2.25204087,
# ...
